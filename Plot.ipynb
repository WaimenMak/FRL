# %% [markdown]
# ### FedSGD

# %%
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')  #生成eps
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import shutil
import os
import pandas as pd
sns.set_style('whitegrid')


# model_path = './outputs/fed_model/pendulum/'
# filename = "eval_None_"
# return_list = np.load(model_path+filename+"server.npy")
# rounds_list = list(range(len(return_list)))
# plt.plot(rounds_list,return_list)
# plt.xlabel('Rounds')
# plt.ylabel('Returns')
# plt.title("Server AvgReturn")
# plt.show()

# mv_return = rl_utils.moving_average(return_list, 9)
# plt.plot(rounds_list, mv_return)
# plt.xlabel('Rounds')
# plt.ylabel('Returns')
# # plt.title('DQN on {}'.format(env_name))
# plt.show()

# %%
# 3 client 2e4 playing step, N = 1, M = 5
# filename = "eval_None_"
return_list = np.load(model_path+filename+"server_clientnum3.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("Server AvgReturn")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
return_list = np.load(model_path+filename+"server_clientnum5.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
#fed_td3_wlker (localdelayupdate) load_state_dict
return_list = np.load(model_path+"evalfed1_None_N1_M5_L1server_clientnum1.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("Server AvgReturn")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
# #fed_td3_wlker (localdelayupdate) load_state_dict
# return_list = np.load(model_path+"evalfed1_None_N1_M5_L1server_clientnum3.npy")
# rounds_list = list(range(len(return_list)))
# plt.plot(rounds_list,return_list)
# plt.xlabel('Rounds')
# plt.ylabel('Returns')
# plt.title("Server AvgReturn")
# # plt.title('DQN on {}'.format(env_name))
# plt.show()

# %%
#fed_td3_wlker (localdelayupdate) load_state_dict
return_list = np.load(model_path+"eval3fed1_None_N1_M5_L1server_clientnum3.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("Server AvgReturn")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
#fed_td3_wlker (localdelayupdate) load_state_dict
return_list = np.load(model_path+"evalfed1_None_N1_M5_L1server_clientnum5.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("Server AvgReturn")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
plt.figure(figsize=(20, 3)) 
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                wspace=0.2, hspace=None)
return_list1 = np.load(model_path+"evalfed1_None_N1_M5_L1server_clientnum1.npy")
rounds_list1 = list(range(len(return_list1)))
plt.subplot(131)
plt.plot(rounds_list1,return_list1)
plt.xlabel('Rounds')
plt.ylabel('Returns')
# plt.title("N1_M5_L1server_clientnum1")
plt.title("1 agent")
# plt.title('DQN on {}'.format(env_name))
#fed_td3_walker localupdate
return_list2 = np.load(model_path+"eval3fed1_None_N1_M5_L1server_clientnum3.npy")
rounds_list2 = list(range(len(return_list2)))
plt.subplot(132)
plt.plot(rounds_list2,return_list2)
plt.xlabel('Rounds')
plt.ylabel('Returns')
# plt.title("N1_M5_L1server_clientnum3")
plt.title("3 agents")

return_list3 = np.load(model_path+"evalfed1_None_N1_M5_L1server_clientnum5.npy")
rounds_list3 = list(range(len(return_list3)))
plt.subplot(133)
plt.plot(rounds_list3,return_list3)
plt.xlabel('Rounds')
plt.ylabel('Returns')
# plt.title("N1_M5_L1server_clientnum5")
plt.title("5 agents")
fig = plt.gcf()
fig.savefig("./fig/fedsgd.jpg")
plt.show()


# plt.savefig("fedsgd.jpg")

# %%
# #fed2_origin (delayupdate) load_state_dict
# return_list = np.load(model_path+"evalori_None_N1_M5_L1server_clientnum3.npy")
# rounds_list = list(range(len(return_list)))
# plt.plot(rounds_list,return_list)
# plt.xlabel('Rounds')
# plt.ylabel('Returns')
# plt.title("Server AvgReturn")
# # plt.title('DQN on {}'.format(env_name))
# plt.show()

# %% [markdown]
# The gradient after aggregate? Adam is not suitable.

# %%
return_list = np.load(model_path+filename+"N1_M5_L1server_clientnum5.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("Server AvgReturn")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
#fed2_origin (delayupdate) load_state_dict
return_list = np.load(model_path+"evalori_None_N1_M5_L1server_clientnum3.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("Server AvgReturn")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %% [markdown]
# ### FedAvg

# %%
return_list = np.load(model_path+filename+"N10_M2_L10server_clientnum5.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("Server AvgReturn")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
return_list = np.load(model_path+filename+"N10_M2_L20server_clientnum5.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("Server AvgReturn")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
return_list = np.load(model_path+filename+"N20_M2_L20server_clientnum5.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("Server AvgReturn")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %% [markdown]
# Theoratically,the more local update of Q net, the harder to converge, because local policy are varied. But empriically, it seem that has little affection to the convergence, but the vaiance is large.

# %%
return_list = np.load(model_path+filename+"N20_M2_L20server_clientnum3.npy")
rounds_list = list(range(len(return_list)))
plt.plot(rounds_list,return_list)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("Server AvgReturn")
# plt.title('DQN on {}'.format(env_name))
# plt.show()

# %% [markdown]
# -----------line------------------

# %%
#fed_td3_walker localupdate 
#10 local q update, 5 agents
return_list4 = np.load(model_path+"evalfedreg_None_N20_M5_L8server_clientnum3.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4,return_list4)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N20_M5_L8server_clientnum3_reg")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
return_list2 = np.load(model_path+"evalfed1_None_N20_M5_L8server_clientnum3.npy")
rounds_list2 = list(range(len(return_list2)))
# plt.subplot(222)
plt.plot(rounds_list2,return_list2)
return_list4 = np.load(model_path+"evalfedreg_None_N20_M5_L8server_clientnum3.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4,return_list4)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N20_M5_L8server_clientnum3")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
#fed_td3_walker localupdate 
#10 local q update, 5 agents beta0.01
return_list4 = np.load(model_path+"evalfedreg_None_N20_M5_L8server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4,return_list4)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N20_M5_L8server_clientnum5_reg")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
return_list2 = np.load(model_path+"eval3fed1_None_N20_M5_L8server_clientnum5.npy")
rounds_list2 = list(range(len(return_list2)))
return_list4 = np.load(model_path+"evalfedreg_None_N20_M5_L8server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(222)
plt.plot(rounds_list2,return_list2)
plt.plot(rounds_list4,return_list4)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N20_M5_L8server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
#fedtd3reg localupdate 
#10 local q update, 5 agents, beta 0.01
return_list4 = np.load(model_path+"eval3fedreg_None_N20_M5_L8server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4,return_list4)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N20_M5_L8server_clientnum5_reg")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
#fedtd3reg localupdate 
#10 local q update, 5 agents
return_list4 = np.load(model_path+"evalfedreg_None_N20_M5_L8_beta0.1server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4,return_list4)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N20_M5_L8server_clientnum5_reg")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
return_list2 = np.load(model_path+"eval3fed1_None_N20_M5_L8server_clientnum5.npy")
rounds_list2 = list(range(len(return_list2)))
return_list4 = np.load(model_path+"eval3fedreg_None_N20_M5_L8server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(222)
plt.plot(rounds_list2,return_list2)
plt.plot(rounds_list4,return_list4)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N20_M5_L8server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
return_list4 = np.load(model_path+"evalfedreg_None_N20_M5_L8_beta0.0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4,return_list4)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N20_M5_L8_beta0server_clientnum3")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
return_list4 = np.load(model_path+"evalfedreg_pendulumNone_N50_M5_L8_beta0.0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
return_list5 = np.load(model_path+"evalfedreg_pendulumNone_N50_M5_L8_beta0.5server_clientnum5.npy")
rounds_list5 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4,return_list4)
plt.plot(rounds_list5,return_list5)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N50_M5_L8_beta0.0server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
n = 10
model_path = './outputs/fed_model/pendulum/'
return_list4 = np.load(model_path+"evalfed1_None_N10_M5_L8server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

return_list5 = np.load(model_path+"evalfedreg_pendulumNone_N10_M2_L20_beta0.0server_clientnum5.npy")
rounds_list5 = list(range(len(return_list4)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 

return_list6 = np.load(model_path+"evalfedreg_pendulumNone_N10_M2_L20_beta0.5server_clientnum5.npy")
rounds_list6 = list(range(len(return_list4)))
mean6 = pd.Series(return_list6).rolling(n).mean()
std6=pd.Series(return_list6).rolling(n).std() 

# plt.subplot(2,2,4)
plt.plot(rounds_list4, mean4)

plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.15)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list4, mean5)
plt.fill_between(range(len(return_list4)),
                 mean5-1.96*std4,
                 mean5+1.96*std4,
                 color='r',
                 alpha=0.15)
plt.plot(rounds_list6,mean6)
plt.fill_between(range(len(return_list4)),
                 mean6-1.96*std4,
                 mean6+1.96*std4,
                 color='g',
                 alpha=0.15)
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N10_M5_L8_server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
# plt.legend(loc='lower right', frameon=False) # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.show()

# %%
pd.Series(return_list4).rolling(5)
# Out:
# Rolling [window=5,center=False,axis=0,method=single]

# %%
model_path = './outputs/fed_model/walker/'
return_list4 = np.load(model_path+"evalfedreg_walkerNone_N1000_M5_L400_beta0.0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4[:500],return_list4[:500])
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N10_M5_L8_beta0.0server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
return_list4 = np.load(model_path+"evalfedreg_pendulum5_N10_M2_L20_beta0.0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4[:500],return_list4[:500])
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N10_M5_L8_beta0.0server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
return_list4 = np.load(model_path+"evalfedreg_pendulum5_N10_M5_L8_beta0.0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4[:500],return_list4[:500])
plt.xlabel('Rounds')
plt.ylabel('Returns')
plt.title("N10_M5_L8_beta0.0server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
#centralize niid
model_path = './outputs/center_model/pendulum/'
return_list4 = np.load(model_path+"normalevalfedreg_pendulum5_M2server_clientnpum5.npy")#no noise  iid
# return_list4 = np.load(model_path+"evalfedreg_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise   niid
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4[:100],return_list4[:100])
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title("N10_M5_L8_beta0.0server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
#decentralize niid FedAvg
model_path = './outputs/fed_model/pendulum/'
# return_list4 = np.load(model_path+"normalevalfedreg_pendulum5_M2server_clientnpum5.npy")#no noise
return_list4 = np.load(model_path+"niidevalfedreg_pendulum5_N10_M2_L20_beta0.0server_clientnum5.npy") #N(0,0.5) noise
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4[:100],return_list4[:100])
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title("N10_M5_L8_beta0.0server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
#decentralize niid FedAvg
model_path = './outputs/fed_model/pendulum/'
return_list3 = np.load(model_path+"niidevalfedreg_pendulum5_N10_M2_L20_beta0.5server_clientnum5.npy")#no noise
return_list4 = np.load(model_path+"niidevalfedmoon_pendulum5_N10_M2_L20_beta0.0server_clientnum5.npy") #N(0,0.5) noise
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4,return_list3)
plt.plot(rounds_list4,return_list4)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title("N10_M5_L8_beta0.0server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
#decentralize niid FedAvg
model_path = './outputs/fed_model/pendulum/'
return_list3 = np.load(model_path+"niidevalfedmoon_pendulum5_N20_M2_L20_beta0.5_mu0server_clientnum5.npy")#no noise
return_list4 = np.load(model_path+"niidevalfedmoon_pendulum5_N20_M2_L20_beta0.0_mu1server_clientnum5.npy") #N(0,0.5) noise
rounds_list4 = list(range(len(return_list4)))
# plt.subplot(2,2,4)
plt.plot(rounds_list4,return_list3)  #fedprox
plt.plot(rounds_list4,return_list4) #moon
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title("N10_M5_L8_beta0.0server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.show()

# %%
n = 7
plt.figure(figsize=(8,8))
model_path = './outputs/fed_model/pendulum/'
return_list4 = np.load(model_path+"niidevalfedreg_pendulum5_N10_M2_L20_beta0.0server_clientnum5.npy") #N(0,0.5) noise
# return_list4 = np.load(model_path+"niidevalfedmoon_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/center_model/pendulum/'
# return_list5 = np.load(model_path+"center_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"centerniid_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 

# model_path = './outputs/center_model/pendulum/'
# return_list6 = np.load(model_path+"normalevalfedreg_pendulum5_M2server_clientnpum5.npy")#no noise  iid
# rounds_list6 = list(range(len(return_list6[:100])))
# mean6 = pd.Series(return_list6[:100]).rolling(n).mean()
# std6=pd.Series(return_list6[:100]).rolling(n).std() 

# model_path = './outputs/fed_model/pendulum/'
# return_list7 = np.load(model_path+"niidevalfedreg_pendulum5_N10_M5_L8_beta0.0server_clientnum5.npy") #N(0,0.5) noise
# rounds_list7 = list(range(len(return_list7)))
# mean7 = pd.Series(return_list7).rolling(n).mean()
# std7=pd.Series(return_list7).rolling(n).std() 

model_path = './outputs/fed_model/pendulum/'
# return_list7 = np.load(model_path+"niidevalfedreg_pendulum5_N10_M2_L10_beta0.0server_clientnum5.npy") #N(0,0.5) noise
return_list7 = np.load(model_path+"niidevalfedmoon_pendulum5_N10_M2_L20_beta0.0server_clientnum5.npy") #N(0,0.5) noise
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 

model_path = './outputs/fed_model/pendulum/'
return_list8 = np.load(model_path+"niidevalfedreg_pendulum5_N10_M2_L20_beta0.5server_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std() 


# plt.subplot(2,2,4)
plt.plot(rounds_list4, mean4, label="fedavg")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# # plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5, label="central")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)

# plt.plot(rounds_list6,mean6)
# plt.fill_between(range(len(return_list6[:100])),
#                  mean6-1.96*std6,
#                  mean6+1.96*std6,
#                  color='y',
#                  alpha=0.15)

plt.plot(rounds_list7,mean7,label="moon")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

plt.plot(rounds_list8,mean8,label="fedprox")
plt.fill_between(range(len(return_list8)),
                 mean8-1.96*std8,
                 mean8+1.96*std8,
                 color='r',
                 alpha=0.1)
plt.xlabel('Per-5-Rounds')
plt.ylabel('Returns')
plt.title("N10_M2_L10_server_clientnum5")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right', frameon=False) # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.show()

# %%
#new 1.5
n = 10
plt.figure(figsize=(9,6))
model_path = './outputs/fed_model/pendulum/'  #fedavg
# return_list4 = np.load(model_path+"niidevalfed3e4_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
return_list4 = np.load(model_path+"niidevalfed_32000_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list4 = np.load(model_path+"niidevalfedmoon_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/center_model/pendulum/'
# return_list5 = np.load(model_path+"center_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"centerniid_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


model_path = './outputs/fed_model/pendulum/'  #moon
return_list7 = np.load(model_path+"niidevalfed3e4_pendulum5_N20_M2_L20_beta0_mu1server_clientnum5.npy") #N(0,0.5) noise
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 

model_path = './outputs/fed_model/pendulum/' #fedprox
return_list8 = np.load(model_path+"niidevalfed3e4_pendulum5_N20_M2_L20_beta0.05_mu0server_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std() 

return_list9 = np.load(model_path+"niidevalfedscaffold_pendulum5_N20_M2_L20server_clientnum5.npy") #N(0,0.5) noise
rounds_list9 = list(range(len(return_list9)))
mean9 = pd.Series(return_list9).rolling(n).mean()
std9=pd.Series(return_list9).rolling(n).std() 

# return_list10 = np.load(model_path+"niidevalfed_pendulum5_N20_M2_L20_beta0_mu0_alpha0.1server_clientnum5.npy") #N(0,0.5) noise
return_list10 = np.load(model_path+"niidevalfeddistil_pendulum5_N20_M2_L20_alpha0.1server_clientnum5.npy") #N(0,0.5) noise
rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std()

return_list11 = np.load(model_path+"niidevalfeddistil_32000_KL_pendulum5_N20_M2_L20_alpha0.01server_clientnum5.npy") #N(0,0.5) noise
rounds_list11 = list(range(len(return_list11)))
mean11 = pd.Series(return_list11).rolling(n).mean()
std11=pd.Series(return_list11).rolling(n).std()

plt.plot(rounds_list4, mean4, label="FedAvg")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5,label="Central")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)


plt.plot(rounds_list7,mean7, label="MOON")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

plt.plot(rounds_list8,mean8,label="FedProx")
plt.fill_between(range(len(return_list8)),
                 mean8-1.96*std8,
                 mean8+1.96*std8,
                 color='r',
                 alpha=0.1)

plt.plot(rounds_list9,mean9,label="Scaffold")
plt.fill_between(range(len(return_list9)),
                 mean9-1.96*std9,
                 mean9+1.96*std9,
                 color='purple',
                 alpha=0.1)

plt.plot(rounds_list10,mean10,label="distil_mse")
plt.fill_between(range(len(return_list10)),
                 mean10-1.96*std10,
                 mean10+1.96*std10,
                 color='brown',
                 alpha=0.1)

plt.plot(rounds_list11,mean11,label="distil_KL")
plt.fill_between(range(len(return_list11)),
                 mean11-1.96*std11,
                 mean11+1.96*std11,
                 color='brown',
                 alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("Pendulum")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':15})
plt.savefig("./fig/pend.jpg")
plt.show()

# %%
#new std=0
n = 10
plt.figure(figsize=(9,7))
model_path = './outputs/fed_model/pendulum/'  #fedavg
# return_list4 = np.load(model_path+"niidevalfed3e4_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
return_list4 = np.load(model_path+"niidevalfedstd0_32000_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list4 = np.load(model_path+"niidevalfedmoon_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/center_model/pendulum/'
# return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


model_path = './outputs/fed_model/pendulum/'  #moon
return_list7 = np.load(model_path+"niidevalfedstd0_32000_pendulum5_N20_M2_L20_beta0_mu0.1server_clientnum5.npy") #N(0,0.5) noise
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 

model_path = './outputs/fed_model/pendulum/' #fedprox
return_list8 = np.load(model_path+"niidevalfedstd0_32000_pendulum5_N20_M2_L20_beta0.05_mu0server_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std() 

return_list9 = np.load(model_path+"niidevalfedscaffold_pendulum5_N20_M2_L20server_clientnum5.npy") #N(0,0.5) noise
rounds_list9 = list(range(len(return_list9)))
mean9 = pd.Series(return_list9).rolling(n).mean()
std9=pd.Series(return_list9).rolling(n).std() 

return_list10 = np.load(model_path+"distilstd0_32000_mse_pendulum5_N20_M2_L20_alpha0.1server_clientnum5.npy") #N(0,0.5) noise
# return_list10 = np.load(model_path+"niidevalfeddistilstd1_32000_mse_pendulum5_N20_M2_L20_alpha0.1server_clientnum5.npy") #N(0,0.5) noise
rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std()

return_list11 = np.load(model_path+"distilstd0_32000_KL_pendulum5_N20_M2_L20_alpha0.01server_clientnum5.npy") #N(0,0.5) noise
rounds_list11 = list(range(len(return_list11)))
mean11 = pd.Series(return_list11).rolling(n).mean()
std11=pd.Series(return_list11).rolling(n).std()

plt.plot(rounds_list4, mean4, label="FedAvg")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5,label="Central")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)

plt.plot(rounds_list7,mean7, label="MOON")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

plt.plot(rounds_list8,mean8,label="FedProx")
plt.fill_between(range(len(return_list8)),
                 mean8-1.96*std8,
                 mean8+1.96*std8,
                 color='r',
                 alpha=0.1)

plt.plot(rounds_list9,mean9,label="Scaffold")
plt.fill_between(range(len(return_list9)),
                 mean9-1.96*std9,
                 mean9+1.96*std9,
                 color='purple',
                 alpha=0.1)

plt.plot(rounds_list10,mean10,label="distil_mse")
plt.fill_between(range(len(return_list10)),
                 mean10-1.96*std10,
                 mean10+1.96*std10,
                 color='brown',
                 alpha=0.1)

# plt.plot(rounds_list11,mean11,label="distil_KL")
# plt.fill_between(range(len(return_list11)),
#                  mean11-1.96*std11,
#                  mean11+1.96*std11,
#                  color='brown',
#                  alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("Pendulum")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':20})
plt.savefig("./fig/pend.jpg")
plt.show()
# no use

# %%
#new dist noisy input
n = 10
plt.figure(figsize=(9,7))
model_path = './outputs/fed_model/pendulum/'  #fedavg
return_list4 = np.load(model_path+"niidevalfedstd0_noicyTrue_30000_pendulum5_N100_M2_L100_beta0_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
# return_list4 = np.load(model_path+"niidevalfedstd0_noicyTrue_32000_pendulum5_N100_M2_L100_beta0_mu0_dist_Falseserver_clientnum5.npy") #N(0,0.5) noise
# return_list4 = np.load(model_path+"niidevalfedmoon_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/center_model/pendulum/'
return_list5 = np.load(model_path+"centerniidstd0_noisyTrue_30000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
# return_list5 = np.load(model_path+"centerniidstd_noisyTrue_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


model_path = './outputs/fed_model/pendulum/'  #moon
return_list7 = np.load(model_path+"niidevalfedstd0_noicyTrue_30000_pendulum5_N100_M2_L100_beta0_mu0.01_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 

model_path = './outputs/fed_model/pendulum/' #fedprox
return_list8 = np.load(model_path+"niidevalfedstd0_noicyTrue_30000_pendulum5_N100_M2_L100_beta0.01_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std() 

return_list9 = np.load(model_path+"niidevalfedscaffold_pendulum5_N100_M2_L100server_clientnum5.npy") #N(0,0.5) noise
rounds_list9 = list(range(len(return_list9)))
mean9 = pd.Series(return_list9).rolling(n).mean()
std9=pd.Series(return_list9).rolling(n).std() 

return_list10 = np.load(model_path+"v3_distilstd0_noicyTrue_30000_pendulum5_N100_M2_L100_criticdualTrue0.1_actordualFalse0.9_reweightFalse0.3_distepoch20_lrdecayFalseserver_clientnum5.npy") #N(0,0.5) noise
# return_list10 = np.load(model_path+"niidevalfeddistilstd1_32000_mse_pendulum5_N20_M2_L20_alpha0.1server_clientnum5.npy") #N(0,0.5) noise
rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std()

return_list11 = np.load(model_path+"qv2_distilstd0_noicyTrue_30000_pendulum5_N100_M2_L100_dualTrue_reweight0.3_distepoch20server_clientnum5.npy") #N(0,0.5) noise
rounds_list11 = list(range(len(return_list11)))
mean11 = pd.Series(return_list11).rolling(n).mean()
std11=pd.Series(return_list11).rolling(n).std()

plt.plot(rounds_list4, mean4, label="FedAvg")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5,label="Central")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)

plt.plot(rounds_list7,mean7, label="MOON")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

plt.plot(rounds_list8,mean8,label="FedProx")
plt.fill_between(range(len(return_list8)),
                 mean8-1.96*std8,
                 mean8+1.96*std8,
                 color='r',
                 alpha=0.1)

# plt.plot(rounds_list9,mean9,label="Scaffold")
# plt.fill_between(range(len(return_list9)),
#                  mean9-1.96*std9,
#                  mean9+1.96*std9,
#                  color='purple',
#                  alpha=0.1)

#dist nor dual
plt.plot(rounds_list10,mean10,label="distil stat reg")
plt.fill_between(range(len(return_list10)),
                 mean10-1.96*std10,
                 mean10+1.96*std10,
                 color='brown',
                 alpha=0.1)

plt.plot(rounds_list11,mean11,label="distil stat")
plt.fill_between(range(len(return_list11)),
                 mean11-1.96*std11,
                 mean11+1.96*std11,
                 color='brown',
                 alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("Pendulum")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':20})
plt.savefig("./fig/pend.jpg")
plt.show()

# %%
#dist std=1
n = 10
plt.figure(figsize=(9,7))
model_path = './outputs/fed_model/pendulum/'  #fedavg
# return_list4 = np.load(model_path+"niidevalfed3e4_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list4 = np.load(model_path+"niidevalfedstd1_noicyFalse_30000_pendulum5_N100_M2_L100_beta0_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
return_list4 = np.load(model_path+"niidevalfedstd1_noicyFalse_30000_pendulum5_N100_M2_L100_beta0_mu0_dual_False_lrdecayFalseserver_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/center_model/pendulum/'
# return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"centerniidstd1_noisyFalse_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = return_list5[:150]
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


model_path = './outputs/fed_model/pendulum/'  #moon
# return_list7 = np.load(model_path+"niidevalfedstd1_noicyFalse_30000_pendulum5_N100_M2_L100_beta0_mu0.01_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
return_list7 = np.load(model_path+"niidevalfedstd1_noicyFalse_30000_pendulum5_N100_M2_L100_beta0_mu0.01_dual_False_lrdecayFalseserver_clientnum5.npy") #N(0,0.5) noise

rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 

model_path = './outputs/fed_model/pendulum/' #fedprox
return_list8 = np.load(model_path+"niidevalfedstd1_noicyFalse_30000_pendulum5_N100_M2_L100_beta0.01_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std() 

return_list9 = np.load(model_path+"fedscaffold_std1_noiseFalse_pendulum5_N100_M2_L100server_clientnum5.npy") #N(0,0.5) noise
rounds_list9 = list(range(len(return_list9)))
mean9 = pd.Series(return_list9).rolling(n).mean()
std9=pd.Series(return_list9).rolling(n).std() 

#dist stat
# return_list10 = np.load(model_path+"v2_distilstd1_noicyFalse_30000_pendulum5_N100_M2_L100_dualFalse_reweight0.3_distepoch20server_clientnum5.npy") #N(0,0.5) noise
return_list10 = np.load(model_path+"v2_distilstd1_noicyFalse_30000_pendulum5_N100_M2_L100_dualFalse_reweightFalse0.3_distepoch20_lrdecayFalseserver_clientnum5.npy") #N(0,0.5) noise
# return_list10 = np.load(model_path+"noreiweightv2_distilstd1_noicyFalse_30000_pendulum5_N100_M2_L100_dualFalse_reweight0.3_distepoch20server_clientnum5.npy") #N(0,0.5) noise
rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std()

#dist reweight
return_list11 = np.load(model_path+"vv_distilstd1_noicyFalse_30000_pendulum5_N100_M2_L100_dualFalse_reweight0.3_distepoch20server_clientnum5.npy") #N(0,0.5) noise
rounds_list11 = list(range(len(return_list11)))
mean11 = pd.Series(return_list11).rolling(n).mean()
std11=pd.Series(return_list11).rolling(n).std()

#dist dual
return_list12 = np.load(model_path+"v3_distilstd1_noicyFalse_30000_pendulum5_N100_M2_L100_criticdualTrue0.1_actordualFalse0.9_reweightFalse0.3_distepoch20_lrdecayFalseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list12 = list(range(len(return_list12)))
mean12 = pd.Series(return_list12).rolling(n).mean()
std12=pd.Series(return_list12).rolling(n).std()

plt.plot(rounds_list4, mean4, label="FedAvg")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)


# plt.plot(rounds_list5, mean5,label="Central")
# plt.fill_between(range(len(return_list5)),
#                  mean5-1.96*std5,
#                  mean5+1.96*std5,
#                  color='orange',
#                  alpha=0.1)

plt.plot(rounds_list7,mean7, label="MOON")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

# plt.plot(rounds_list8,mean8,label="FedProx")
# plt.fill_between(range(len(return_list8)),
#                  mean8-1.96*std8,
#                  mean8+1.96*std8,
#                  color='r',
#                  alpha=0.1)

# plt.plot(rounds_list9,mean9,label="Scaffold")
# plt.fill_between(range(len(return_list9)),
#                  mean9-1.96*std9,
#                  mean9+1.96*std9,
#                  color='purple',
#                  alpha=0.1)

# #dist stat
plt.plot(rounds_list10,mean10,label="distil stat")
plt.fill_between(range(len(return_list10)),
                 mean10-1.96*std10,
                 mean10+1.96*std10,
                 color='brown',
                 alpha=0.1)

# plt.plot(rounds_list11,mean11,label="distil")
# plt.fill_between(range(len(return_list11)),
#                  mean11-1.96*std11,
#                  mean11+1.96*std11,
#                  color='yellow',
#                  alpha=0.1)

plt.plot(rounds_list12,mean12,label="distil v3")
plt.fill_between(range(len(return_list11)),
                 mean11-1.96*std11,
                 mean11+1.96*std11,
                 color='brown',
                 alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("Pendulum")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':20})
plt.savefig("./fig/pend.jpg")
plt.show()

# %%
#new std=0 noisy input
n = 5
plt.figure(figsize=(11,8))
model_path = './outputs/fed_model/cartpole/'  #fedavg
# return_list4 = np.load(model_path+"niidevalfed3e4_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
return_list4 = np.load(model_path+"niidevalfedstd0_noicyTrue_20000_cart5_N20_M2_L20_beta0_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
# return_list4 = np.load(model_path+"niidevalfedstd0_noicyTrue_20000_cart5_N20_M2_L20_beta0_mu0_dist_Falseserver_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/center_model/cartpole/'
# return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"centerniidstd_noisyTrue_20000_cart5_M2server_clientnpum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


model_path = './outputs/fed_model/cartpole/'  #moon
# return_list7 = np.load(model_path+"niidevalfedstd0_noicyTrue_20000_cart5_N20_M2_L20_beta0_mu0.01_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
return_list7 = np.load(model_path+"niidevalfedstd0_noicyTrue_20000_cart5_N20_M2_L20_beta0_mu0.01_dual_False_lrdecayFalseserver_clientnum5.npy") #N(0,0.5) noise

rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 

model_path = './outputs/fed_model/cartpole/' #fedprox
return_list8 = np.load(model_path+"niidevalfedstd0_noicyTrue_20000_cart5_N20_M2_L20_beta0.01_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std() 

return_list9 = np.load(model_path+"fedscaffold_std0_noiseTrue_cart5_N20_M2_L20server_clientnum5.npy") #N(0,0.5) noise
rounds_list9 = list(range(len(return_list9)))
mean9 = pd.Series(return_list9).rolling(n).mean()
std9=pd.Series(return_list9).rolling(n).std() 

#dist_stat  #capacity 10000 & 6000
# return_list10 = np.load(model_path+"v2_distilstd0_noicyTrue_20000_cart5_N20_M2_L20_dualFalse_reweightTrue_distepoch10server_clientnum5.npy") #N(0,0.5) noise
return_list10 = np.load(model_path+"v2_distilstd0_noicyTrue_20000_cart5_N20_M2_L20_dualFalse_reweightFalse0.5_distepoch10_lrdecayFalseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std()

#dist no reg                          distilstd0_noicyTrue_20000_cart5_N20_M2_L20_dualFalse_reweightTrue_distepoch10server_clientnum5
# return_list11 = np.load(model_path+"distilstd0_noicyTrue_20000_cart5_N20_M2_L20_alpha0server_clientnum5.npy") #N(0,0.5) noise
return_list11 = np.load(model_path+"distilstd0_noicyTrue_20000_cart5_N20_M2_L20_dualFalse_reweightTrue_distepoch10server_clientnum5.npy") #N(0,0.5) noise
rounds_list11 = list(range(len(return_list11)))
mean11 = pd.Series(return_list11).rolling(n).mean()
std11=pd.Series(return_list11).rolling(n).std()

#dist with reg, reweight
# return_list12 = np.load(model_path+"distilstd0_noicyTrue_20000_cart5_N20_M2_L20_dualTrue_reweightTrue_distepoch10server_clientnum5.npy") #N(0,0.5) noise
# # return_list12 = np.load(model_path+"v2_distilstd0_noicyTrue_20000_cart5_N20_M2_L20_dualFalse_distepoch10server_clientnum5.npy") #N(0,0.5) noise
# rounds_list12 = list(range(len(return_list12)))
# mean12 = pd.Series(return_list12).rolling(n).mean()
# std12=pd.Series(return_list12).rolling(n).std()

# plt.plot(rounds_list4, mean4, label="FedAvg")
# plt.fill_between(range(len(return_list4)),
#                  mean4-1.96*std4,
#                  mean4+1.96*std4,
#                  color='b',
#                  alpha=0.1)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5,label="Central")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)

plt.plot(rounds_list7,mean7, label="MOON")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

# plt.plot(rounds_list8,mean8,label="FedProx")
# plt.fill_between(range(len(return_list8)),
#                  mean8-1.96*std8,
#                  mean8+1.96*std8,
#                  color='r',
#                  alpha=0.1)

# plt.plot(rounds_list9,mean9,label="Scaffold")
# plt.fill_between(range(len(return_list9)),
#                  mean9-1.96*std9,
#                  mean9+1.96*std9,
#                  color='purple',
#                  alpha=0.1)

plt.plot(rounds_list10,mean10,label="distil_stat") 
plt.fill_between(range(len(return_list10)),
                 mean10-1.96*std10,
                 mean10+1.96*std10,
                 color='brown',
                 alpha=0.1)

# plt.plot(rounds_list11,mean11,label="distil")
# plt.fill_between(range(len(return_list11)),
#                  mean11-1.96*std11,
#                  mean11+1.96*std11,
#                  color='brown',
#                  alpha=0.1)

# plt.plot(rounds_list12,mean12,label="distil_dual")
# plt.fill_between(range(len(return_list12)),
#                  mean12-1.96*std12,
#                  mean12+1.96*std12,
#                  color='brown',
#                  alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("CartPole")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':10})
plt.savefig("./fig/pend.jpg")
plt.show()
# Out:
# D:\Applications\Anaconda\anaconda\lib\site-packages\ipykernel_launcher.py:126: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
#cart diffenent env params std=1
n = 5
plt.figure(figsize=(9,9))
model_path = './outputs/fed_model/cartpole/'  #fedavg
# return_list4 = np.load(model_path+"niidevalfed3e4_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
return_list4 = np.load(model_path+"niidevalfedstd1_noicyFalse_20000_cart5_N20_M2_L20_beta0_mu0_dual_False_lrdecayFalseserver_clientnum5.npy") #N(0,0.5) noise
# return_list4 = np.load(model_path+"niidevalfedstd1_noicyFalse_20000_cart5_N20_M2_L20_beta0_mu0_dual_Falseserver_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/center_model/cartpole/' #center
# return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"centerniidstd_noisyFalse_20000_cart5_M2server_clientnpum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


model_path = './outputs/fed_model/cartpole/'  #moon
return_list7 = np.load(model_path+"niidevalfedstd1_noicyFalse_20000_cart5_N20_M2_L20_beta0_mu0.01_dual_False_lrdecayFalseserver_clientnum5.npy") #N(0,0.5) noise
# return_list7 = np.load(model_path+"niidevalfedstd1_noicyFalse_20000_cart5_N20_M2_L20_beta0_mu0.01_dual_False_lrdecayTrueserver_clientnum5.npy") #N(0,0.5) noise
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 

model_path = './outputs/fed_model/cartpole/' #fedprox
return_list8 = np.load(model_path+"niidevalfedstd1_noicyFalse_20000_cart5_N20_M2_L20_beta0.01_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std() 
                                            #scaffold
return_list9 = np.load(model_path+"cartstd1niidevalfedscaffold_cart5_N20_M2_L20server_clientnum5.npy") #N(0,0.5) noise
rounds_list9 = list(range(len(return_list9)))
mean9 = pd.Series(return_list9).rolling(n).mean()
std9=pd.Series(return_list9).rolling(n).std() 

#dist_reweight
# return_list10 = np.load(model_path+"distilstd1_noicyFalse_20000_cart5_N20_M2_L20_dualFalse_reweightTrue_distepoch10server_clientnum5.npy") #N(0,0.5) noise
return_list10 = np.load(model_path+"distilstd1_noicyFalse_20000_cart5_N20_M2_L20_dualFalse_reweight0.5_distepoch10server_clientnum5.npy") #N(0,0.5) noise
rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std()

#dist no reg
# return_list11 = np.load(model_path+"distilstd1_noicyFalse_20000_cart5_N20_M2_L20_dualTrue_reweightTrue_distepoch10server_clientnum5.npy") #N(0,0.5) noise
# # return_list11 = np.load(model_path+"distilstd1_noicyFalse_20000_cart5_N20_M2_L20_dualFalse_distepoch10server_clientnum5.npy") #N(0,0.5) noise
# rounds_list11 = list(range(len(return_list11)))
# mean11 = pd.Series(return_list11).rolling(n).mean()
# std11=pd.Series(return_list11).rolling(n).std()

#dist with reg
return_list12 = np.load(model_path+"distilstd1_noicyFalse_20000_cart5_N20_M2_L20_dualTrue_reweightTrue_distepoch10server_clientnum5.npy") #N(0,0.5) noise
# return_list12 = np.load(model_path+"v2_distilstd1_noicyFalse_20000_cart1_N20_M2_L20_dualTrue_reweightTrue_distepoch10server_clientnum1.npy") #N(0,0.5) noise
rounds_list12 = list(range(len(return_list12)))
mean12 = pd.Series(return_list12).rolling(n).mean()
std12=pd.Series(return_list12).rolling(n).std()

#dist stat
# return_list13 = np.load(model_path+"v2_distilstd1_noicyFalse_20000_cart5_N20_M2_L20_dualFalse_reweight0.5_distepoch10server_clientnum5.npy") #N(0,0.5) noise
# return_list13 = np.load(model_path+"noreweightv2_distilstd1_noicyFalse_20000_cart5_N20_M2_L20_dualFalse_reweight0.5_distepoch10server_clientnum5.npy") #N(0,0.5) noi
return_list13 = np.load(model_path+"v2_distilstd1_noicyFalse_20000_cart5_N20_M2_L20_dualFalse_reweightFalse0.5_distepoch10_lrdecayFalseserver_clientnum5.npy") #N(0,0.5) noi
rounds_list13 = list(range(len(return_list13)))
mean13 = pd.Series(return_list13).rolling(n).mean()
std13=pd.Series(return_list13).rolling(n).std()

plt.plot(rounds_list4, mean4, label="FedAvg")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5,label="Central")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)

plt.plot(rounds_list7,mean7, label="MOON")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

# plt.plot(rounds_list8,mean8,label="FedProx")
# plt.fill_between(range(len(return_list8)),
#                  mean8-1.96*std8,
#                  mean8+1.96*std8,
#                  color='r',
#                  alpha=0.1)

# plt.plot(rounds_list9,mean9,label="Scaffold")
# plt.fill_between(range(len(return_list9)),
#                  mean9-1.96*std9,
#                  mean9+1.96*std9,
#                  color='purple',
#                  alpha=0.1)

# plt.plot(rounds_list10,mean10,label="distil") 
# plt.fill_between(range(len(return_list10)),
#                  mean10-1.96*std10,
#                  mean10+1.96*std10,
#                  color='brown',
#                  alpha=0.1)

# plt.plot(rounds_list11,mean11,label="distil_nodual")
# plt.fill_between(range(len(return_list11)),
#                  mean11-1.96*std11,
#                  mean11+1.96*std11,
#                  color='brown',
#                  alpha=0.1)

# plt.plot(rounds_list12,mean12,label="distil_dual")
# plt.fill_between(range(len(return_list12)),
#                  mean12-1.96*std12,
#                  mean12+1.96*std12,
#                  color='brown',
#                  alpha=0.1)

plt.plot(rounds_list13,mean13,label="distil_stat")
plt.fill_between(range(len(return_list13)),
                 mean13-1.96*std13,
                 mean13+1.96*std13,
                 color='brown',
                 alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("CartPole")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':10})
plt.savefig("./fig/pend.jpg")
plt.show()
# Out:
# D:\Applications\Anaconda\anaconda\lib\site-packages\ipykernel_launcher.py:140: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
#lunar
n = 5
plt.figure(figsize=(7,6))
model_path = './outputs/fed_model/lunar/'  #fedavg
return_list4 = np.load(
    model_path+"niidevalfedstd1_noicyFalse_120000_lunar5_N300_M4_L150_beta0_mu0_dual_False_lrdecayFalse_line_1.npy"
) #N(0,0.5) noise
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/center_model/lunar/'
# return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"centerniidstd_noisyFalse_360000_lunar5_M4server_clientnpum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


model_path = './outputs/fed_model/lunar/'  #moon
return_list7 = np.load(model_path+"niidevalfedstd1_noicyFalse_120000_lunar5_N300_M4_L150_beta0_mu0.01_dual_False_lrdecayFalse_line_1.npy") #N(0,0.5) noise
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 

# model_path = './outputs/fed_model/lunar/' #fedprox
# return_list8 = np.load(model_path+"niidevalfedstd0_noicyTrue_20000_cart5_N20_M2_L20_beta0.01_mu0server_clientnum5.npy") #N(0,0.5) noise
# rounds_list8 = list(range(len(return_list8)))
# mean8 = pd.Series(return_list8).rolling(n).mean()
# std8=pd.Series(return_list8).rolling(n).std() 

# return_list9 = np.load(model_path+"niidevalfedscaffold_cart5_N20_M2_L20server_clientnum5.npy") #N(0,0.5) noise
# rounds_list9 = list(range(len(return_list9)))
# mean9 = pd.Series(return_list9).rolling(n).mean()
# std9=pd.Series(return_list9).rolling(n).std() 

#dist
return_list10 = np.load(model_path+"v3_distilstd0_noicyFalse_120000_lunar5_N300_M4_L150_criticdualTrue0.1_actordualFalse0.9_reweightFalse1_distepoch10_lrdecayFalse_line_1.npy")
rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std()

return_list11 = np.load(model_path+"ttdistilstd0_noicyFalse_360000_lunar1_N300_M4_L150_alpha0server_clientnum1.npy") #N(0,0.5) noise
rounds_list11 = list(range(len(return_list11)))
mean11 = pd.Series(return_list11).rolling(n).mean()
std11=pd.Series(return_list11).rolling(n).std()

plt.plot(rounds_list4, mean4, label="FedAvg")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# plt.plot(rounds_list5,return_list5)
# plt.plot(rounds_list5, mean5,label="Central")
# plt.fill_between(range(len(return_list5)),
#                  mean5-1.96*std5,
#                  mean5+1.96*std5,
#                  color='orange',
#                  alpha=0.1)

plt.plot(rounds_list7,mean7, label="MOON")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

# plt.plot(rounds_list8,mean8,label="FedProx")
# plt.fill_between(range(len(return_list8)),
#                  mean8-1.96*std8,
#                  mean8+1.96*std8,
#                  color='r',
#                  alpha=0.1)

# plt.plot(rounds_list9,mean9,label="Scaffold")
# plt.fill_between(range(len(return_list9)),
#                  mean9-1.96*std9,
#                  mean9+1.96*std9,
#                  color='purple',
#                  alpha=0.1)

plt.plot(rounds_list10,mean10,label="distil_v3")
plt.fill_between(range(len(return_list10)),
                 mean10-1.96*std10,
                 mean10+1.96*std10,
                 color='brown',
                 alpha=0.1)

# plt.plot(rounds_list11,mean11,label="distil_KL")
# plt.fill_between(range(len(return_list11)),
#                  mean11-1.96*std11,
#                  mean11+1.96*std11,
#                  color='brown',
#                  alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("Lunar")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':20})
plt.savefig("./fig/pend.jpg")
plt.show()

# %%
#lunar newnetwork
n = 5
plt.figure(figsize=(7,6))
model_path = './outputs/fed_model/lunar/'  #fedavg
return_list4 = np.load(
    model_path+"niidevalfedstd0_noicyFalse_360000_lunar5_N300_M4_L150_beta0_mu0_dual_Falseserver_clientnum5.npy"
) #N(0,0.5) noise
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/center_model/lunar/'
# return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"centerniidstd_noisyFalse_360000_lunar5_M4server_clientnpum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


model_path = './outputs/fed_model/lunar/'  #moon
# return_list7 = np.load(model_path+"niidevalfedstd0_noicyTrue_20000_cart5_N20_M2_L20_beta0_mu0.01server_clientnum5.npy") #N(0,0.5) noise
# rounds_list7 = list(range(len(return_list7)))
# mean7 = pd.Series(return_list7).rolling(n).mean()
# std7=pd.Series(return_list7).rolling(n).std() 

# model_path = './outputs/fed_model/lunar/' #fedprox
# return_list8 = np.load(model_path+"niidevalfedstd0_noicyTrue_20000_cart5_N20_M2_L20_beta0.01_mu0server_clientnum5.npy") #N(0,0.5) noise
# rounds_list8 = list(range(len(return_list8)))
# mean8 = pd.Series(return_list8).rolling(n).mean()
# std8=pd.Series(return_list8).rolling(n).std() 

# return_list9 = np.load(model_path+"niidevalfedscaffold_cart5_N20_M2_L20server_clientnum5.npy") #N(0,0.5) noise
# rounds_list9 = list(range(len(return_list9)))
# mean9 = pd.Series(return_list9).rolling(n).mean()
# std9=pd.Series(return_list9).rolling(n).std() 

#dist
return_list10 = np.load(model_path+"distilstd0_noicyFalse_360000_lunar1_N300_M4_L150_alpha0server_clientnum1.npy")
rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std()

return_list11 = np.load(model_path+"ttdistilstd0_noicyFalse_360000_lunar1_N300_M4_L150_alpha0server_clientnum1.npy") #N(0,0.5) noise
rounds_list11 = list(range(len(return_list11)))
mean11 = pd.Series(return_list11).rolling(n).mean()
std11=pd.Series(return_list11).rolling(n).std()

plt.plot(rounds_list4, mean4, label="FedAvg")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5,label="Central")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)

# plt.plot(rounds_list7,mean7, label="MOON")
# plt.fill_between(range(len(return_list7)),
#                  mean7-1.96*std7,
#                  mean7+1.96*std7,
#                  color='g',
#                  alpha=0.1)

# plt.plot(rounds_list8,mean8,label="FedProx")
# plt.fill_between(range(len(return_list8)),
#                  mean8-1.96*std8,
#                  mean8+1.96*std8,
#                  color='r',
#                  alpha=0.1)

# plt.plot(rounds_list9,mean9,label="Scaffold")
# plt.fill_between(range(len(return_list9)),
#                  mean9-1.96*std9,
#                  mean9+1.96*std9,
#                  color='purple',
#                  alpha=0.1)

plt.plot(rounds_list10,mean10,label="distil_mse")
plt.fill_between(range(len(return_list10)),
                 mean10-1.96*std10,
                 mean10+1.96*std10,
                 color='brown',
                 alpha=0.1)

plt.plot(rounds_list11,mean11,label="distil_KL")
plt.fill_between(range(len(return_list11)),
                 mean11-1.96*std11,
                 mean11+1.96*std11,
                 color='brown',
                 alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("Lunar")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':20})
plt.savefig("./fig/pend.jpg")
plt.show()

# %%
#decentralize niid FedAvg walker
n=30
model_path = './outputs/center_model/walker/'


plt.figure(figsize=(9,6))
# return_list4 = np.load(model_path+"centerniid1.2e_walkerNone_M2server_clientnpum5.npy")#no noise
return_list4 = np.load(model_path+"centerniid__1200000_walkerNone_M2server_clientnpum5.npy")#no noise
# return_list4 = np.load(model_path+"niidevalfedmoon_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/fed_model/walker/'
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0.01server_clientnum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0.001server_clientnum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std()


# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0.005_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list6 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
return_list6 = np.load(model_path+"niidevalfed1.2e_walker5_N400_M2_L400_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
rounds_list6 = list(range(len(return_list6)))
mean6 = pd.Series(return_list6).rolling(n).mean()
std6=pd.Series(return_list6).rolling(n).std() 

# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0.005_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
return_list7 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0.005_mu0server_clientnum5.npy") #N(0,0.5) noise
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std()

return_list8 = np.load(model_path+"niidevalfedscaffold_walker5_N400_M2_L400server_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std()

return_list9 = np.load(model_path+"niidevalfeddistil_walker5_N400_M2_L400_alpha0.001server_clientnum5.npy") #N(0,0.5) noise
rounds_list9 = list(range(len(return_list9)))
mean9 = pd.Series(return_list9).rolling(n).mean()
std9=pd.Series(return_list9).rolling(n).std() 

plt.plot(rounds_list4, mean4, label="Central")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)


plt.plot(rounds_list5, mean5,label="MOON")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='y',
                 alpha=0.1)


plt.plot(rounds_list6, mean6,label="FedAvg")
plt.fill_between(range(len(return_list6)),
                 mean6-1.96*std6,
                 mean6+1.96*std6,
                 color='g',
                 alpha=0.1)

# plt.plot(rounds_list7, mean7,label="FedProx")
# plt.fill_between(range(len(return_list7)),
#                  mean7-1.96*std7,
#                  mean7+1.96*std7,
#                  color='r',
#                  alpha=0.1)

plt.plot(rounds_list8, mean8,label="Scaffold")
plt.fill_between(range(len(return_list8)),
                 mean8-1.96*std8,
                 mean8+1.96*std8,
                 color='purple',
                 alpha=0.1)

plt.plot(rounds_list9,mean9,label="Q_mse")
plt.fill_between(range(len(return_list9)),
                 mean9-1.96*std9,
                 mean9+1.96*std9,
                 color='purple',
                 alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
plt.title("BipedalWalkerHardcore")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':10})
# plt.savefig("./fig/walker.jpg")
plt.show()

# %%
#distillation newnetwork
n=30
model_path = './outputs/center_model/walker/'


plt.figure(figsize=(9,6))
# return_list4 = np.load(model_path+"centerniid1.2e_walkerNone_M2server_clientnpum5.npy")#no noise
return_list4 = np.load(model_path+"centerniid__1200000_walkerNone_M2server_clientnpum5.npy")#no noise
# return_list4 = np.load(model_path+"niidevalfedmoon_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/fed_model/walker/'
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0.01server_clientnum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0.001server_clientnum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std()

#fedavg
return_list6 = np.load(model_path+"niidevalfedstd0_noicyFalse_1200000_walker5_N400_M2_L400_beta0_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
# return_list6 = np.load(model_path+"walkerv2niidevalfedstd0_noicyFalse_1200000_walker5_N400_M2_L400_beta0_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list6 = list(range(len(return_list6)))
mean6 = pd.Series(return_list6).rolling(n).mean()
std6=pd.Series(return_list6).rolling(n).std() 

# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0.005_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
return_list7 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0.005_mu0server_clientnum5.npy") #N(0,0.5) noise
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std()

return_list8 = np.load(model_path+"niidevalfedscaffold_walker5_N400_M2_L400server_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std()

return_list9 = np.load(model_path+"v2_distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalse_reweight0.5_distepoch20server_clientnum5.npy") #N(0,0.5) noise
rounds_list9 = list(range(len(return_list9)))
mean9 = pd.Series(return_list9).rolling(n).mean()
std9=pd.Series(return_list9).rolling(n).std() 

# return_list10 = np.load(model_path+"distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalseserver_clientnum5.npy") #N(0,0.5) noise
return_list10 = np.load(model_path+"distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalse_distepoch15server_clientnum5.npy") #N(0,0.5) noise

rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std() 

# plt.plot(rounds_list4, mean4, label="Central")
# plt.fill_between(range(len(return_list4)),
#                  mean4-1.96*std4,
#                  mean4+1.96*std4,
#                  color='b',
#                  alpha=0.1)


# plt.plot(rounds_list5, mean5,label="MOON")
# plt.fill_between(range(len(return_list5)),
#                  mean5-1.96*std5,
#                  mean5+1.96*std5,
#                  color='y',
#                  alpha=0.1)


plt.plot(rounds_list6, mean6,label="FedAvg")
plt.fill_between(range(len(return_list6)),
                 mean6-1.96*std6,
                 mean6+1.96*std6,
                 color='g',
                 alpha=0.1)

# plt.plot(rounds_list7, mean7,label="FedProx")
# plt.fill_between(range(len(return_list7)),
#                  mean7-1.96*std7,
#                  mean7+1.96*std7,
#                  color='r',
#                  alpha=0.1)

# plt.plot(rounds_list8, mean8,label="Scaffold")
# plt.fill_between(range(len(return_list8)),
#                  mean8-1.96*std8,
#                  mean8+1.96*std8,
#                  color='purple',
#                  alpha=0.1)

plt.plot(rounds_list9,mean9,label="dist stat")
plt.fill_between(range(len(return_list9)),
                 mean9-1.96*std9,
                 mean9+1.96*std9,
                 color='purple',
                 alpha=0.1)

plt.plot(rounds_list10,mean10,label="dist no dual")
plt.fill_between(range(len(return_list10)),
                 mean9-1.96*std10,
                 mean9+1.96*std10,
                 color='purple',
                 alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
plt.title("BipedalWalkerHardcore")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':10})
# plt.savefig("./fig/walker.jpg")
plt.show()

# %%
#distillation newnetwork walker v2
n=30
model_path = './outputs/center_model/walker/'


plt.figure(figsize=(9,6))
# return_list4 = np.load(model_path+"centerniid1.2e_walkerNone_M2server_clientnpum5.npy")#no noise
return_list4 = np.load(model_path+"centerniid__1200000_walkerNone_M2server_clientnpum5.npy")#no noise
# return_list4 = np.load(model_path+"niidevalfedmoon_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/fed_model/walker/'
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0.01server_clientnum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0.001server_clientnum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std()

#fedavg
return_list6 = np.load(model_path+"walkerv2niidevalfedstd0_noicyFalse_1200000_walker5_N400_M2_L400_beta0_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list6 = list(range(len(return_list6)))
mean6 = pd.Series(return_list6).rolling(n).mean()
std6=pd.Series(return_list6).rolling(n).std() 

# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0.005_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
return_list7 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0.005_mu0server_clientnum5.npy") #N(0,0.5) noise
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std()

return_list8 = np.load(model_path+"niidevalfedscaffold_walker5_N400_M2_L400server_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std()

#dist_stat
return_list9 = np.load(model_path+"v2_distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalse_reweightTrue_distepoch20server_clientnum5.npy") #N(0,0.5) noise
rounds_list9 = list(range(len(return_list9)))
mean9 = pd.Series(return_list9).rolling(n).mean()
std9=pd.Series(return_list9).rolling(n).std() 

# return_list10 = np.load(model_path+"distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalseserver_clientnum5.npy") #N(0,0.5) noise
return_list10 = np.load(model_path+"distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalse_distepoch15server_clientnum5.npy") #N(0,0.5) noise

rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std() 

# plt.plot(rounds_list4, mean4, label="Central")
# plt.fill_between(range(len(return_list4)),
#                  mean4-1.96*std4,
#                  mean4+1.96*std4,
#                  color='b',
#                  alpha=0.1)


# plt.plot(rounds_list5, mean5,label="MOON")
# plt.fill_between(range(len(return_list5)),
#                  mean5-1.96*std5,
#                  mean5+1.96*std5,
#                  color='y',
#                  alpha=0.1)


plt.plot(rounds_list6, mean6,label="FedAvg")
plt.fill_between(range(len(return_list6)),
                 mean6-1.96*std6,
                 mean6+1.96*std6,
                 color='g',
                 alpha=0.1)

# plt.plot(rounds_list7, mean7,label="FedProx")
# plt.fill_between(range(len(return_list7)),
#                  mean7-1.96*std7,
#                  mean7+1.96*std7,
#                  color='r',
#                  alpha=0.1)

# plt.plot(rounds_list8, mean8,label="Scaffold")
# plt.fill_between(range(len(return_list8)),
#                  mean8-1.96*std8,
#                  mean8+1.96*std8,
#                  color='purple',
#                  alpha=0.1)

plt.plot(rounds_list9,mean9,label="dist_stat")
plt.fill_between(range(len(return_list9)),
                 mean9-1.96*std9,
                 mean9+1.96*std9,
                 color='purple',
                 alpha=0.1)

plt.plot(rounds_list10,mean10,label="dist")
plt.fill_between(range(len(return_list10)),
                 mean9-1.96*std10,
                 mean9+1.96*std10,
                 color='purple',
                 alpha=0.1)

plt.xlabel('Episodes')
plt.ylabel('Average Returns')
plt.title("BipedalWalkerHardcore")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':10})
# plt.savefig("./fig/walker.jpg")
plt.show()

# %%
#distillation newnetwork walker v3
n=20
model_path = './outputs/center_model/walker/'


plt.figure(figsize=(9,6))
# return_list4 = np.load(model_path+"centerniid1.2e_walkerNone_M2server_clientnpum5.npy")#no noise
return_list4 = np.load(model_path+"centerniid__1200000_walkerNone_M2server_clientnpum5.npy")#no noise
# return_list4 = np.load(model_path+"niidevalfedmoon_pendulum5_N20_M2_L20_beta0_mu0server_clientnum5.npy")
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

model_path = './outputs/fed_model/walker/'
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0.01server_clientnum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"niidevalfedstd0_noicyFalse_1200000_walker5_N400_M2_L400_beta0_mu0.01_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std()

#fedavg
return_list6 = np.load(model_path+"v3niidevalfedstd0_noicyFalse_1200000_walker5_N400_M2_L400_beta0_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list6 = list(range(len(return_list6)))
mean6 = pd.Series(return_list6).rolling(n).mean()
std6=pd.Series(return_list6).rolling(n).std() 

# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0.005_mu0server_clientnum5.npy") #N(0,0.5) noise
# return_list5 = np.load(model_path+"niidevalfed_walker5_N400_M2_L400_beta0_mu0server_clientnum5.npy") #N(0,0.5) noise
return_list7 = np.load(model_path+"niidevalfedstd0_noicyFalse_1200000_walker5_N400_M2_L400_beta0.01_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std()

return_list8 = np.load(model_path+"niidevalfedscaffold_walker5_N400_M2_L400server_clientnum5.npy") #N(0,0.5) noise
rounds_list8 = list(range(len(return_list8)))
mean8 = pd.Series(return_list8).rolling(n).mean()
std8=pd.Series(return_list8).rolling(n).std()

#dist_stat
return_list9 = np.load(model_path+"v2_distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalse_reweight0.5_distepoch20server_clientnum5.npy") #N(0,0.5) noise
rounds_list9 = list(range(len(return_list9)))
mean9 = pd.Series(return_list9).rolling(n).mean()
std9=pd.Series(return_list9).rolling(n).std() 

# return_list10 = np.load(model_path+"distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalseserver_clientnum5.npy") #N(0,0.5) noise
# return_list10 = np.load(model_path+"v2_distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalse_reweight1_distepoch20server_clientnum5.npy") #N(0,0.5) noise
return_list10 = np.load(model_path+"v2_distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalse_reweightFalse1_distepoch20_lrdecayTrueserver_clientnum5.npy") 
rounds_list10 = list(range(len(return_list10)))
mean10 = pd.Series(return_list10).rolling(n).mean()
std10=pd.Series(return_list10).rolling(n).std() 

return_list11 = np.load(model_path+"distilstd0_noicyFalse_1200000_walker5_N400_M2_L400_dualFalse_reweight0.5_distepoch20server_clientnum5.npy") #N(0,0.5) noise
rounds_list11 = list(range(len(return_list11)))
mean11 = pd.Series(return_list11).rolling(n).mean()
std11=pd.Series(return_list11).rolling(n).std() 

return_list12 = np.load(model_path+"reweight0.5niidfedstd0_noicyFalse_1200000_walker5_N400_M2_L400_beta0_mu0_dual_Falseserver_clientnum5.npy") #N(0,0.5) noise
rounds_list12 = list(range(len(return_list12)))
mean12 = pd.Series(return_list12).rolling(n).mean()
std12=pd.Series(return_list12).rolling(n).std() 

# plt.plot(rounds_list4, mean4, label="Central")
# plt.fill_between(range(len(return_list4)),
#                  mean4-1.96*std4,
#                  mean4+1.96*std4,
#                  color='b',
#                  alpha=0.1)


# plt.plot(rounds_list5, mean5,label="MOON")
# plt.fill_between(range(len(return_list5)),
#                  mean5-1.96*std5,
#                  mean5+1.96*std5,
#                  color='y',
#                  alpha=0.1)


plt.plot(rounds_list6, mean6,label="FedAvg")
plt.fill_between(range(len(return_list6)),
                 mean6-1.96*std6,
                 mean6+1.96*std6,
                 color='g',
                 alpha=0.1)

# plt.plot(rounds_list7, mean7,label="FedProx")
# plt.fill_between(range(len(return_list7)),
#                  mean7-1.96*std7,
#                  mean7+1.96*std7,
#                  color='r',
#                  alpha=0.1)

# plt.plot(rounds_list8, mean8,label="Scaffold")
# plt.fill_between(range(len(return_list8)),
#                  mean8-1.96*std8,
#                  mean8+1.96*std8,
#                  color='purple',
#                  alpha=0.1)

plt.plot(rounds_list9,mean9,label="dist_stat")
plt.fill_between(range(len(return_list9)),
                 mean9-1.96*std9,
                 mean9+1.96*std9,
                 color='purple',
                 alpha=0.1)

# plt.plot(rounds_list10,mean10,label="dist_stat2")
# plt.fill_between(range(len(return_list10)),
#                  mean10-1.96*std10,
#                  mean10+1.96*std10,
#                  color='purple',
#                  alpha=0.1)

# plt.plot(rounds_list11,mean11,label="dist")
# plt.fill_between(range(len(return_list11)),
#                  mean11-1.96*std11,
#                  mean11+1.96*std11,
#                  color='purple',
#                  alpha=0.1)

plt.plot(rounds_list12, mean12,label="FedAvg reweight")
plt.fill_between(range(len(return_list12)),
                 mean12-1.96*std12,
                 mean12+1.96*std12,
#                  color='g',
                 alpha=0.1)


plt.xlabel('Episodes')
plt.ylabel('Average Returns')
plt.title("BipedalWalkerHardcore")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
plt.rcParams.update({'font.size':10})
# plt.savefig("./fig/walker.jpg")
plt.show()

# %%
#cart diffenent env params std=1
n = 5
plt.style.use("seaborn-darkgrid")
plt.figure(figsize=(9,4))

model_path = './outputs/fed_model/cartpole/'  #fedavg
return_list4 = np.load(model_path+"env_std0agentagent0.npy",allow_pickle=True)
return_list4 = return_list4[:,0]
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

# return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"env_std0agentagent1.npy",allow_pickle=True) #N(0,0.5) noise
return_list5 = return_list5[:,0]
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


return_list7 = np.load(model_path+"env_std0agentagent2.npy",allow_pickle=True) #N(0,0.5) noise
return_list7 = return_list7[:,0]
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 

plt.subplot(1,2,1)
plt.plot(rounds_list4, mean4, label="Local Env 1")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5,label="Local Env 2")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)

plt.plot(rounds_list7,mean7, label="Local Env 3")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

x = np.arange(0,200)
y = np.ones(200) * 180.8
plt.plot(x, y, linestyle='--', color = "black")

# plt.xlabel('Episodes')
plt.ylabel('Average Return')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("Identical environment parameters")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
# plt.rcParams.update({'font.size':10})



return_list4 = np.load(model_path+"env_std1agentagent0.npy",allow_pickle=True)
return_list4 = return_list4[:,0]
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

# return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"env_std1agentagent1.npy",allow_pickle=True) #N(0,0.5) noise
return_list5 = return_list5[:,0]
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


model_path = './outputs/fed_model/cartpole/'  #moon
return_list7 = np.load(model_path+"env_std1agentagent2.npy",allow_pickle=True) #N(0,0.5) noise
return_list7 = return_list7[:,0]
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 


plt.subplot(1,2,2)
plt.plot(rounds_list4, mean4, label="Local Env 1")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5,label="Local Env 2")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)

plt.plot(rounds_list7,mean7, label="Local Env 3")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

x = np.arange(0,200)
y = np.ones(200) * 106.27
plt.plot(x, y, linestyle='--', color = "black")

# plt.xlabel('Episodes')
plt.ylabel('Average Return')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("Different environment parameters")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
# plt.rcParams.update({'font.size':10})
# plt.savefig("./fig/illustrate.jpg")
plt.show()
# plt.savefig(fname="./fig/illus.pdf",format="pdf")
# Out:
# D:\Applications\Anaconda\anaconda\lib\site-packages\ipykernel_launcher.py:123: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
np.random.seed(5) #0.5, 0.1, 1, 9.8
std = 1
length = 1. + np.random.normal(0, std) #length
length = np.clip(length, 0.5, 1.5)
masspole = 1. + np.random.normal(0, std)  # masspole
masspole = np.clip(masspole, 0.5, 1.5)
# torque = np.random.uniform(1, 3, 1)[0]  # masscart
gravity = 10. + np.random.normal(0, std)  # gravity
gravity = np.clip(gravity, 8, 12)
length, masspole, gravity
# Out:
# (1.4412274868850414, 0.6691298481059124, 12.0)

# %%
np.random.randint(1, 3)
# Out:
# 1

# %%
import torch
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
def select(seed=None):
    state = range(1, 4)
    # 概率列表
    if not seed:
        r = [1/3,1/3,1/3]
    else:
        np.random.seed(seed)
        r = np.random.dirichlet(np.ones(3)).tolist()
    print(r)
    sum = 0
    ran_num = random.random()
    for state, r in zip(state, r):
        sum += r
        if ran_num < sum:
            break
    return state
a = select(1)
a
# Out:
# [0.2974927278529054, 0.7024442120019875, 6.306014510719398e-05]
# 2

# %%
#cart diffenent env params std=1
# matplotlib.use('Agg')  #生成eps
n = 5
plt.style.use("seaborn-darkgrid")
plt.figure(figsize=(10,7))

model_path = './outputs/fed_model/cartpole/'  #fedavg
return_list4 = np.load(model_path+"env_std0agentagent0.npy",allow_pickle=True)
return_list4 = return_list4[:,0]
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

# return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"env_std0agentagent1.npy",allow_pickle=True) #N(0,0.5) noise
return_list5 = return_list5[:,0]
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


return_list7 = np.load(model_path+"env_std0agentagent2.npy",allow_pickle=True) #N(0,0.5) noise
return_list7 = return_list7[:,0]
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 

plt.subplot(2,2,1)
plt.plot(rounds_list4, mean4, label="Local Env 1")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5,label="Local Env 2")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)

plt.plot(rounds_list7,mean7, label="Local Env 3")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

x = np.arange(0,200)
y = np.ones(200) * 180.8
plt.plot(x, y, linestyle='--', color = "black")

# plt.xlabel('Episodes')
plt.ylabel('Average Return')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("Identical environment parameters")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面
# plt.legend(loc=8, frameon=False, bbox_to_anchor=(0.5,-0.3))# 图例在图形外面
# plt.rcParams.update({'font.size':10})



return_list4 = np.load(model_path+"env_std1agentagent0.npy",allow_pickle=True)
return_list4 = return_list4[:,0]
rounds_list4 = list(range(len(return_list4)))
mean4 = pd.Series(return_list4).rolling(n).mean()
std4=pd.Series(return_list4).rolling(n).std() 

# return_list5 = np.load(model_path+"centerniidstd1_32000_pendulum5_M2server_clientnpum5.npy") #N(0,0.5) noise
return_list5 = np.load(model_path+"env_std1agentagent1.npy",allow_pickle=True) #N(0,0.5) noise
return_list5 = return_list5[:,0]
rounds_list5 = list(range(len(return_list5)))
mean5 = pd.Series(return_list5).rolling(n).mean()
std5=pd.Series(return_list5).rolling(n).std() 


model_path = './outputs/fed_model/cartpole/'  #moon
return_list7 = np.load(model_path+"env_std1agentagent2.npy",allow_pickle=True) #N(0,0.5) noise
return_list7 = return_list7[:,0]
rounds_list7 = list(range(len(return_list7)))
mean7 = pd.Series(return_list7).rolling(n).mean()
std7=pd.Series(return_list7).rolling(n).std() 


plt.subplot(2,2,2)
plt.plot(rounds_list4, mean4, label="Local Env 1")
plt.fill_between(range(len(return_list4)),
                 mean4-1.96*std4,
                 mean4+1.96*std4,
                 color='b',
                 alpha=0.1)

# plt.plot(rounds_list5,return_list5)
plt.plot(rounds_list5, mean5,label="Local Env 2")
plt.fill_between(range(len(return_list5)),
                 mean5-1.96*std5,
                 mean5+1.96*std5,
                 color='orange',
                 alpha=0.1)

plt.plot(rounds_list7,mean7, label="Local Env 3")
plt.fill_between(range(len(return_list7)),
                 mean7-1.96*std7,
                 mean7+1.96*std7,
                 color='g',
                 alpha=0.1)

x = np.arange(0,200)
y = np.ones(200) * 106.27
plt.plot(x, y, linestyle='--', color = "black")

# plt.xlabel('Episodes')
plt.ylabel('Average Return')
# plt.title("N20_M2_L20_server_clientnum5")
plt.title("Different environment parameters")
# plt.title('DQN on {}'.format(env_name))
plt.legend(loc='lower right') # 图例在图形里面

model_path = './outputs/fed_model/cartpole/'
colorid = ["b","orange","g"]
bc = 256
# plt.style.use("seaborn-darkgrid")
# plt.figure(figsize=(9,4))
# a = torch.load(model_path+"iidclient5agent0.pt")
a = np.load(model_path+"envagent0.npy")
b = np.load(model_path+"envagent1.npy")
c = np.load(model_path+"envagent2.npy")
X = np.concatenate([a, b, c])
# b = torch.load(model_path+"iidclient5agent1.pt")
# c = torch.load(model_path+"iidclient5agent2.pt")
# d = torch.load(model_path+"iidclient5agent3.pt")
# e = torch.load(model_path+"iidclient5agent4.pt")
# X = torch.cat([a,b,c,d,e]).numpy()
label = np.zeros([X.shape[0]])
for i in range(3):
    label[i*bc:i*bc+bc] = i+1
tsne = TSNE(n_components=2, init='pca', random_state=0)
result = tsne.fit_transform(X)
x_min, x_max = np.min(result, 0), np.max(result, 0)
data = (result - x_min) / (x_max - x_min)
data=result
plt.subplot(2,2,3)
for i in range(X.shape[0]//bc):
    plt.plot(data[i*bc:i*bc+bc,0], data[i*bc:i*bc+bc,1], '.',color=colorid[i],label=f"Local Env {int(label[i*bc])}")
#     plt.plot(data[i*bc:i*bc+bc,0], data[i*bc:i*bc+bc,1], '.',color=colorid[i],label=f"Local Env {int(label[i*bc])}")

plt.legend(loc='lower right') # 图例在图形里面    

a = np.load(model_path+"niidenvagent0.npy")
b = np.load(model_path+"niidenvagent1.npy")
c = np.load(model_path+"niidenvagent2.npy")
X = np.concatenate([a, b, c])
label = np.zeros([X.shape[0]])
for i in range(3):
    label[i*bc:i*bc+bc] = i+1
tsne = TSNE(n_components=2, init='pca', random_state=0)
result = tsne.fit_transform(X)
x_min, x_max = np.min(result, 0), np.max(result, 0)
data = (result - x_min) / (x_max - x_min)
data=result
plt.subplot(2,2,4)
for i in range(X.shape[0]//bc):
    plt.plot(data[i*bc:i*bc+bc,0], data[i*bc:i*bc+bc,1], '.',label=f"Local Env {int(label[i*bc])}")   
    
plt.legend()
plt.legend(loc='lower left') # 图例在图形里面
plt.rcParams.update({'font.size':10})
             
             
plt.show()
# plt.savefig(fname="./fig/illus2.0.pdf",format="pdf")
# Out:
# D:\Applications\Anaconda\anaconda\lib\site-packages\ipykernel_launcher.py:173: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.

# %%
model_path = './outputs/fed_model/cartpole/'
bc = 256
a = torch.load(model_path+"agent0.pt")
b = torch.load(model_path+"agent1.pt")
c = torch.load(model_path+"agent2.pt")
d = torch.load(model_path+"agent3.pt")
e = torch.load(model_path+"agent4.pt")
X = torch.cat([a,b,c,d,e]).numpy()
label = np.zeros([X.shape[0]])
for i in range(5):
    label[i*bc:i*bc+bc] = i+1

# %%
tsne = TSNE(n_components=2, init='pca', random_state=0)
result = tsne.fit_transform(X)

# %%
i=0
plt.plot(result[i*bc:i*bc+bc,0], result[i*bc:i*bc+bc,1], '.',color=plt.cm.Set1(label[i] / 10.))

# %%
x_min, x_max = np.min(result, 0), np.max(result, 0)
data = (result - x_min) / (x_max - x_min)
for i in range(X.shape[0]//bc):
    plt.plot(data[i*bc:i*bc+bc,0], data[i*bc:i*bc+bc,1], '.',color=plt.cm.Set1(label[i*bc] / 10.),label=label[i*bc])
plt.legend()
plt.legend(loc='lower right') # 图例在图形里面
plt.rcParams.update({'font.size':10})

# %%
model_path = './outputs/fed_model/cartpole/'
ls = []
for i in range(5):
    ls.append(torch.load(model_path+f"agent{i}.pt").numpy())

# %%
data = []
for i in range(5):
    mean = np.mean(ls[i],axis=0)
    cov = np.cov(ls[i].T)
    a1 = np.random.multivariate_normal(mean, cov, 256)
    data.append(a1)
result =  np.concatenate(data)

# %%
tsne = TSNE(n_components=2, init='pca', random_state=0)
result = tsne.fit_transform(result)

# %%
#gaussian noise after tsne
x_min, x_max = np.min(result, 0), np.max(result, 0)
data = (result - x_min) / (x_max - x_min)
# data = result
for i in range(X.shape[0]//bc):
    plt.plot(data[i*bc:i*bc+bc,0], data[i*bc:i*bc+bc,1], '.',color=plt.cm.Set1(label[i*bc] / 10.),label=label[i*bc])
plt.legend()
plt.legend(loc='lower right') # 图例在图形里面
plt.rcParams.update({'font.size':10})

# %%
#gaussian data without tsne
data = result
data[data < 0] = 0
for i in range(X.shape[0]//bc):
    plt.plot(data[i*bc:i*bc+bc,9], data[i*bc:i*bc+bc,10], '.',color=plt.cm.Set1(label[i*bc] / 10.),label=label[i*bc])
plt.legend()
plt.legend(loc='lower right') # 图例在图形里面
plt.rcParams.update({'font.size':10})

# %%
#representation
data = X
for i in range(X.shape[0]//bc):
    plt.plot(data[i*bc:i*bc+bc,9], data[i*bc:i*bc+bc,10], '.',color=plt.cm.Set1(label[i*bc] / 10.),label=label[i*bc])
plt.legend()
plt.legend(loc='lower right') # 图例在图形里面
plt.rcParams.update({'font.size':10})

# %%
mean = np.mean(ls[1],axis=0)
cov = np.cov(ls[1].T)
i=1
data = np.random.multivariate_normal(mean, cov, 256)
plt.plot(data[:,2], data[:,3], '.',color=plt.cm.Set1(1 / 10.),label=1)

# %%
model_path = './outputs/fed_model/cartpole/'
bc = 256
a = torch.load(model_path+"client3agent0.pt")
b = torch.load(model_path+"client3agent1.pt")
c = torch.load(model_path+"client3agent2.pt")

X = torch.cat([a,b,c]).numpy()
label = np.zeros([X.shape[0]])
for i in range(3):
    label[i*bc:i*bc+bc] = i+1
    
tsne = TSNE(n_components=2, init='pca', random_state=0)
result = tsne.fit_transform(X)
x_min, x_max = np.min(result, 0), np.max(result, 0)
data = (result - x_min) / (x_max - x_min)

for i in range(X.shape[0]//bc):
    plt.plot(data[i*bc:i*bc+bc,0], data[i*bc:i*bc+bc,1], '.',color=plt.cm.Set1(label[i*bc] / 10.),label=label[i*bc])
plt.legend()
plt.legend(loc='lower right') # 图例在图形里面
plt.rcParams.update({'font.size':10})

# %%
np.random.seed(1)
np.random.dirichlet(np.ones(4),size=1)
# Out:
# array([[2.48224944e-01, 5.86112396e-01, 5.26167518e-05, 1.65610043e-01]])

# %%
import pickle
from queue import deque
d = deque()

# %%
d.append((1))
d
# Out:
# deque([1, 1])

# %%
pickle.dump(d, open('object', 'wb'))

# %%
with open('object', 'rb') as f:  
    s = pickle.loads(f.read())
